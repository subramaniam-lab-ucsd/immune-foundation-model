# %% [markdown]
# # Immune Data Preprocessing

# %%
import anndata as ad
import pandas as pd
import scanpy as sc

# %%
## Set data folder
data_path = "../data/cellxgene_data"

# %%
## Load CZI immune data

adata1 = ad.read_h5ad(f"{data_path}/immune_cells_chunk0.h5ad") # chunk 1
adata2 = ad.read_h5ad(f"{data_path}/immune_cells_chunk1.h5ad") # chunk 2

# Axis 0 = cells
adata_full = ad.concat([adata1, adata2], axis=0, join="outer", merge="same")
for field in adata_full.obs.keys().tolist():
    if pd.api.types.is_categorical_dtype(adata_full.obs[field]):
        adata_full.obs[field] = adata_full.obs[field].cat.remove_unused_categories() # remove unused categories
adata_full.write_h5ad(f"{data_path}/immune_1M_merged.h5ad") # write to single .h5ad
# Out:
# /home/s5srinivasan/immune-foundational-model/.venv/lib64/python3.11/site-packages/anndata/_core/anndata.py:1774: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /tmp/ipykernel_1613178/3272363573.py:9: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(adata_full.obs[field]):

# %% [markdown]
# ## Inspection

# %%
## Inspect

adata_full.obs
# Out:
#         soma_joinid                            dataset_id      assay  \
# 0           4276120  d18736c3-6292-4379-919a-d6d973204c87  10x 3' v3
# 1           4276173  d18736c3-6292-4379-919a-d6d973204c87  10x 3' v3
# 2           4276224  d18736c3-6292-4379-919a-d6d973204c87  10x 3' v3
# 3           4276469  d18736c3-6292-4379-919a-d6d973204c87  10x 3' v3
# 4           4276566  d18736c3-6292-4379-919a-d6d973204c87  10x 3' v3
# ...             ...                                   ...        ...
# 499995    106479716  53d208b0-2cfd-4366-9866-c3c6114081bc  10x 3' v3
# 499996    106479735  53d208b0-2cfd-4366-9866-c3c6114081bc  10x 3' v3
# 499997    106479739  53d208b0-2cfd-4366-9866-c3c6114081bc  10x 3' v3
# 499998    106479761  53d208b0-2cfd-4366-9866-c3c6114081bc  10x 3' v3
# 499999    106479766  53d208b0-2cfd-4366-9866-c3c6114081bc  10x 3' v3
#
#                                               cell_type  \
# 0       effector memory CD4-positive, alpha-beta T cell
# 1        central memory CD4-positive, alpha-beta T cell
# 2                                    gamma-delta T cell
# 3        central memory CD4-positive, alpha-beta T cell
# 4                                    classical monocyte
# ...                                                 ...
# 499995                                         pericyte
# 499996                                         basophil
# 499997                                        club cell
# 499998                  CD4-positive, alpha-beta T cell
# 499999                   pulmonary alveolar type 2 cell
#
#        cell_type_ontology_term_id     development_stage  \
# 0                      CL:0000905     young adult stage
# 1                      CL:0000904     young adult stage
# 2                      CL:0000798           adult stage
# 3                      CL:0000904  60-79 year-old stage
# 4                      CL:0000860  60-79 year-old stage
# ...                           ...                   ...
# 499995                 CL:0000669     60-year-old stage
# 499996                 CL:0000767     60-year-old stage
# 499997                 CL:0000158     60-year-old stage
# 499998                 CL:0000624     60-year-old stage
# 499999                 CL:0002063     60-year-old stage
#
#        development_stage_ontology_term_id disease disease_ontology_term_id  \
# 0                          HsapDv:0000266  normal             PATO:0000461
# 1                          HsapDv:0000266  normal             PATO:0000461
# 2                          HsapDv:0000258  normal             PATO:0000461
# 3                          HsapDv:0000272  normal             PATO:0000461
# 4                          HsapDv:0000272  normal             PATO:0000461
# ...                                   ...     ...                      ...
# 499995                     HsapDv:0000154  normal             PATO:0000461
# 499996                     HsapDv:0000154  normal             PATO:0000461
# 499997                     HsapDv:0000154  normal             PATO:0000461
# 499998                     HsapDv:0000154  normal             PATO:0000461
# 499999                     HsapDv:0000154  normal             PATO:0000461
#
#                donor_id observation_joinid self_reported_ethnicity  \
# 0       Control10_1_C_F         WE&Q3GE(19                European
# 1       Control10_1_C_F         D(*#;_I22y                European
# 2       Control15_1_C_F         %KsHiyf)`1                European
# 3       Control07_1_C_F         z~n6JxbiyO                European
# 4       Control07_1_C_F         >{%;4*}I|S                European
# ...                 ...                ...                     ...
# 499995            TSP25         DHu5I+@`x_                   Asian
# 499996            TSP25         A%cQ~Y$sCM                   Asian
# 499997            TSP25         9^j1cWgF3%                   Asian
# 499998            TSP25         W5>{{cBDJk                   Asian
# 499999            TSP25         Tv1?|QxKx5                   Asian
#
#        self_reported_ethnicity_ontology_term_id     sex sex_ontology_term_id  \
# 0                                HANCESTRO:0005  female         PATO:0000383
# 1                                HANCESTRO:0005  female         PATO:0000383
# 2                                HANCESTRO:0005  female         PATO:0000383
# 3                                HANCESTRO:0005  female         PATO:0000383
# 4                                HANCESTRO:0005  female         PATO:0000383
# ...                                         ...     ...                  ...
# 499995                           HANCESTRO:0008    male         PATO:0000384
# 499996                           HANCESTRO:0008    male         PATO:0000384
# 499997                           HANCESTRO:0008    male         PATO:0000384
# 499998                           HANCESTRO:0008    male         PATO:0000384
# 499999                           HANCESTRO:0008    male         PATO:0000384
#
#        tissue_general tissue_general_ontology_term_id
# 0               blood                  UBERON:0000178
# 1               blood                  UBERON:0000178
# 2               blood                  UBERON:0000178
# 3               blood                  UBERON:0000178
# 4               blood                  UBERON:0000178
# ...               ...                             ...
# 499995           lung                  UBERON:0002048
# 499996           lung                  UBERON:0002048
# 499997           lung                  UBERON:0002048
# 499998           lung                  UBERON:0002048
# 499999           lung                  UBERON:0002048
#
# [1000000 rows x 17 columns]
